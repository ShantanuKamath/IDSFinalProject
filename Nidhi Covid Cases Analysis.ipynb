# %%
import pandas as pd

# %%
raw_df = pd.read_csv('/Users/upendradhar/Downloads/United_States_COVID-19_Cases_and_Deaths_by_State_over_Time.csv')
raw_df['submission_date'] = pd.to_datetime(raw_df['submission_date'])
raw_df.head()
# Out:
#   submission_date state  tot_cases  conf_cases  prob_cases  new_case  \
# 0      2021-02-12    UT     359641    359641.0         0.0      1060
# 1      2021-03-01    CO     438745    411869.0     26876.0       677
# 2      2020-08-22    AR      56199         NaN         NaN       547
# 3      2020-08-12    AS          0         NaN         NaN         0
# 4      2020-06-05    HI        661         NaN         NaN         8
#
#    pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 0        0.0       1785      1729.0        56.0         11         2.0
# 1       60.0       5952      5218.0       734.0          1         0.0
# 2        0.0        674         NaN         NaN         11         0.0
# 3        0.0          0         NaN         NaN          0         0.0
# 4        0.0         17         NaN         NaN          0         0.0
#
#                created_at consent_cases consent_deaths
# 0  02/13/2021 02:50:08 PM         Agree          Agree
# 1  03/01/2021 12:00:00 AM         Agree          Agree
# 2  08/23/2020 02:15:28 PM     Not agree      Not agree
# 3  08/13/2020 02:12:28 PM           NaN            NaN
# 4  06/06/2020 10:31:37 AM     Not agree      Not agree

# %%
raw_df.sort_values('submission_date', axis=0, ascending=True, inplace=True)

# %%
raw_df = raw_df.rename(columns={"submission_date": "Date", "tot_cases": "Total Cases", "new_case": "Daily New Cases", "state":"State"})

# %%
raw_df.head()
# Out:
#             Date State  Total Cases  conf_cases  prob_cases  Daily New Cases  \
# 9539  2020-01-22    WI            0         NaN         NaN                0
# 6471  2020-01-22   RMI            0         NaN         NaN                0
# 14034 2020-01-22    ID            0         NaN         NaN                0
# 20347 2020-01-22    ND            0         NaN         NaN                0
# 13260 2020-01-22    MT            0         NaN         NaN                0
#
#        pnew_case  tot_death  conf_death  prob_death  new_death  pnew_death  \
# 9539         NaN          0         NaN         NaN          0         NaN
# 6471         NaN          0         NaN         NaN          0         NaN
# 14034        NaN          0         NaN         NaN          0         NaN
# 20347        NaN          0         NaN         NaN          0         NaN
# 13260        NaN          0         NaN         NaN          0         NaN
#
#                    created_at consent_cases consent_deaths
# 9539   03/26/2020 04:22:39 PM         Agree          Agree
# 6471   03/26/2020 04:22:39 PM         Agree          Agree
# 14034  03/26/2020 04:22:39 PM         Agree          Agree
# 20347  03/26/2020 04:22:39 PM         Agree      Not agree
# 13260  03/26/2020 04:22:39 PM         Agree          Agree

# %%
state_df = raw_df[['Date', 'State', "Total Cases", "Daily New Cases"]]

# %%
state_df.head()
# Out:
#             Date State  Total Cases  Daily New Cases
# 9539  2020-01-22    WI            0                0
# 6471  2020-01-22   RMI            0                0
# 14034 2020-01-22    ID            0                0
# 20347 2020-01-22    ND            0                0
# 13260 2020-01-22    MT            0                0

# %%
state_df.groupby(['Date']).count()
# Out:
#             State  Total Cases  Daily New Cases
# Date
# 2020-01-22     60           60               60
# 2020-01-23     60           60               60
# 2020-01-24     60           60               60
# 2020-01-25     60           60               60
# 2020-01-26     60           60               60
# ...           ...          ...              ...
# 2021-11-17     60           60               60
# 2021-11-18     60           60               60
# 2021-11-19     60           60               60
# 2021-11-20     60           60               60
# 2021-11-21     60           60               60
#
# [670 rows x 3 columns]

# %%
country_df = raw_df.groupby(['Date']).agg({'Total Cases':'sum','Daily New Cases':'sum'}).reset_index()

# %%
country_df.head()
# Out:
#         Date  Total Cases  Daily New Cases
# 0 2020-01-22            0                0
# 1 2020-01-23            1                1
# 2 2020-01-24            2                1
# 3 2020-01-25            2                0
# 4 2020-01-26            3                1

# %%
country_df.isnull().any()
# Out:
# Date               False
# Total Cases        False
# Daily New Cases    False
# dtype: bool

# %%
(country_df['Total Cases'] < 0).values.any()
# Out:
# False

# %%
(country_df['Daily New Cases'] < 0).values.any()
# Out:
# False

# %%
country_df.to_csv('/Users/upendradhar/IDSFinalProject/Data/usa_national_level_daily_new_covid_cases.csv', index=False)

# %%
state_df.to_csv('/Users/upendradhar/IDSFinalProject/Data/usa_state_level_daily_new_covid_cases.csv', index=False)

# %%
raw_df.to_csv('/Users/upendradhar/IDSFinalProject/Data/source/raw_daily_state_level_covid_cases.csv', index=False)
